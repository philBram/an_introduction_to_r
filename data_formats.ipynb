# %% [markdown]
# ## Numeric

# %%
n1 <- 15
print(n1)
# Out:
# [1] 15

# %%
typeof(n1)
# Out:
# [1] "double"

# %%
n2 <- 1.5
print(n2)
# Out:
# [1] 1.5

# %%
typeof(n2)
# Out:
# [1] "double"

# %%
n3 <- 15L
print(n3)
# Out:
# [1] 15

# %%
typeof(n3)
# Out:
# [1] "integer"

# %% [markdown]
# ## Character

# %%
c1 <- 'c'
print(c1)
# Out:
# [1] "c"

# %%
typeof(c1)
# Out:
# [1] "character"

# %%
c2 <- 'a string of text'
print(c2)
# Out:
# [1] "a string of text"

# %%
typeof(c2)
# Out:
# [1] "character"

# %% [markdown]
# ## Logical

# %%
l1 <- TRUE
#l1 <- T
print(l1)
# Out:
# [1] TRUE

# %%
typeof(l1)
# Out:
# [1] "logical"

# %%
l2 <- FALSE
#l2 <- F
print(l2)
# Out:
# [1] FALSE

# %%
typeof(l2)
# Out:
# [1] "logical"

# %% [markdown]
# ## Vector

# %%
v1 <- c(2, 1, 3, 5)
print(v1)
# Out:
# [1] 2 1 3 5

# %%
is.vector(v1)
# Out:
# [1] TRUE

# %%
v2 <- c('a', 'b', 'c')
print(v2)
# Out:
# [1] "a" "b" "c"

# %%
is.vector(v2)
# Out:
# [1] TRUE

# %%
v3 <- c(T, T, F, FALSE, TRUE)
print(v3)
# Out:
# [1]  TRUE  TRUE FALSE FALSE  TRUE

# %%
is.vector(v3)
# Out:
# [1] TRUE

# %% [markdown]
# ## Matrix

# %%
m1 <- matrix(c(T, T, F, F, T, F), nrow = 2)
print(m1)
# Out:
#      [,1]  [,2]  [,3]
# [1,] TRUE FALSE  TRUE
# [2,] TRUE FALSE FALSE

# %%
is.matrix(m1)
# Out:
# [1] TRUE

# %%
m2 <- matrix(c('a', 'b',
               'c', 'd'),
                nrow = 2,
                byrow = T)

print(m2)
# Out:
#      [,1] [,2]
# [1,] "a"  "b"
# [2,] "c"  "d"

# %%
m3 <- matrix(c('a', 'b',
               'c', 'd'),
                nrow = 2,
                byrow = F)

print(m3)
# Out:
#      [,1] [,2]
# [1,] "a"  "c"
# [2,] "b"  "d"

# %% [markdown]
# ## Array

# %%
a1 <- array(c(1:24), dim = c(4, 3, 2))
print(a1)
# Out:
# , , 1
#
#      [,1] [,2] [,3]
# [1,]    1    5    9
# [2,]    2    6   10
# [3,]    3    7   11
# [4,]    4    8   12
#
# , , 2
#
#      [,1] [,2] [,3]
# [1,]   13   17   21
# [2,]   14   18   22
# [3,]   15   19   23
# [4,]   16   20   24

# %%
is.array(a1)
# Out:
# [1] TRUE

# %%
print(a1[2, 2, 2])
# Out:
# [1] 18

# %% [markdown]
# ## Data frame

# %%
v_numeric <- c(1, 2, 3)
v_character <- c('a', 'b', 'c')
v_logical <- c(T, F, T)
df1 <- as.data.frame(cbind(v_numeric, v_character, v_logical))
df1
# Out:
#   v_numeric v_character v_logical
# 1 1         a           TRUE
# 2 2         b           FALSE
# 3 3         c           TRUE

# %% [markdown]
# ## List

# %%
o1 <- c(1, 2, 3)
o2 <- c('a', 'b', 'c', 'd')
o3 <- c(T, F, T, T, F)

list1 <- list(o1, o2, o3)
print(list1)
# Out:
# [[1]]
# [1] 1 2 3
#
# [[2]]
# [1] "a" "b" "c" "d"
#
# [[3]]
# [1]  TRUE FALSE  TRUE  TRUE FALSE

# %%
list1[[1]][2]
# Out:
# [1] 2

# %%
list2 <- list(o1, o2, o3, list1)
print(list2)
# Out:
# [[1]]
# [1] 1 2 3
#
# [[2]]
# [1] "a" "b" "c" "d"
#
# [[3]]
# [1]  TRUE FALSE  TRUE  TRUE FALSE
#
# [[4]]
# [[4]][[1]]
# [1] 1 2 3
#
# [[4]][[2]]
# [1] "a" "b" "c" "d"
#
# [[4]][[3]]
# [1]  TRUE FALSE  TRUE  TRUE FALSE

# %%
list2[[4]][[2]][3]
# Out:
# [1] "c"

# %% [markdown]
# ## COERCING TYPES

# %% [markdown]
# ### Automatic coercion

# %%
# Goes to "least restrictive" data type

print(coerce1 <- c(1, 'b', T))
typeof(coerce1)
# Out:
# [1] "1"    "b"    "TRUE"
# [1] "character"

# %%
# Coerce numeric to integer

print(coerce2 <- 5)
typeof(coerce2)

print(coerce3 <- as.integer(5))
typeof(coerce3)
# Out:
# [1] 5
# [1] "double"
# [1] 5
# [1] "integer"

# %%
# Coerce charactar to numeric

print(coerce4 <- c('1', '2', '3'))
typeof(coerce4)

print(coerce5 <- as.numeric(c('1', '2', '3')))
typeof(coerce5)
# Out:
# [1] "1" "2" "3"
# [1] "character"
# [1] 1 2 3
# [1] "double"

# %%
# Coerce matrix to data frame

print(coerce6 <- matrix(1:9, nrow = 3))
is.matrix(coerce6)

coerce7 <- as.data.frame(matrix(1:9, nrow = 3, byrow = T))
coerce7
#print(coerce7 <- as.data.frame(coerce6))
is.data.frame(coerce7)
# Out:
#      [,1] [,2] [,3]
# [1,]    1    4    7
# [2,]    2    5    8
# [3,]    3    6    9
# [1] TRUE
#   V1 V2 V3
# 1 1  2  3
# 2 4  5  6
# 3 7  8  9
# [1] TRUE

# %%
coerce7[coerce7$V3 == 9 | coerce7$V3 == 3, ]$V1
# Out:
# [1] 1 7

# %%
x <- c(1:3)
y <- rep(c(1:10), each = 3)
df <- as.data.frame(cbind(x, y))
df$x <- factor(df$x, levels = c(1, 2, 3), labels = c('x', 'y', 'z'))
str(df)
# Out:
# 'data.frame':	30 obs. of  2 variables:
#  $ x: Factor w/ 3 levels "x","y","z": 1 2 3 1 2 3 1 2 3 1 ...
#  $ y: int  1 1 1 2 2 2 3 3 3 4 ...

# %%
df[order(-df$y), ][c(1:5), ]
# Out:
#    x y
# 28 x 10
# 29 y 10
# 30 z 10
# 25 x  9
# 26 y  9

# %%
library(datasets)
library(psych)

# %%
head(iris)
# Out:
#   Sepal.Length Sepal.Width Petal.Length Petal.Width Species
# 1 5.1          3.5         1.4          0.2         setosa
# 2 4.9          3.0         1.4          0.2         setosa
# 3 4.7          3.2         1.3          0.2         setosa
# 4 4.6          3.1         1.5          0.2         setosa
# 5 5.0          3.6         1.4          0.2         setosa
# 6 5.4          3.9         1.7          0.4         setosa

# %%
options(repr.plot.width = 15, repr.plot.height = 8)
hist(iris$Petal.Length, cex.main = 2, cex.lab = 1.5, cex.axis = 1.5)
# Out:
# Plot with title “Histogram of iris$Petal.Length”

# %%
summary(iris$Petal.Length)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   1.000   1.600   4.350   3.758   5.100   6.900

# %%
summary(iris$Species)
# Out:
#     setosa versicolor  virginica
#         50         50         50

# %%
par(mfrow = c(4, 1), cex.main = 2, cex.axis = 1.5, cex.lab = 1.5)
options(repr.plot.height = 15)

hist(iris$Petal.Length[iris$Species == 'setosa'], breaks = 'FD')

hist(iris$Petal.Length[iris$Species == 'versicolor'], breaks = 'FD')

hist(iris$Petal.Length[iris$Species == 'virginica'], breaks = 'FD', freq = FALSE)
lines(density(iris$Petal.Length[iris$Species == 'virginica'], adjust = 2))

hist(iris$Petal.Length[iris$Petal.Length < 1.5])
# Out:
# Plot with title “Histogram of iris$Petal.Length[iris$Petal.Length < 1.5]”

# %%
options(repr.plot.height = 8)
hist(iris$Petal.Length[iris$Species == 'virginica' & iris$Petal.Length < 5.5])
# Out:
# Plot with title “Histogram of iris$Petal.Length[iris$Species == "virginica" & iris$Petal.Length < 5.5]”

# %%
setosa <- iris[iris$Species == 'setosa', c('Species', 'Petal.Length')]

# %%
head(setosa)
# Out:
#   Species Petal.Length
# 1 setosa  1.4
# 2 setosa  1.4
# 3 setosa  1.3
# 4 setosa  1.5
# 5 setosa  1.4
# 6 setosa  1.7

# %%
i.setosa <- iris[iris$Species == 'setosa', ]

# %%
head(i.setosa)
# Out:
#   Sepal.Length Sepal.Width Petal.Length Petal.Width Species
# 1 5.1          3.5         1.4          0.2         setosa
# 2 4.9          3.0         1.4          0.2         setosa
# 3 4.7          3.2         1.3          0.2         setosa
# 4 4.6          3.1         1.5          0.2         setosa
# 5 5.0          3.6         1.4          0.2         setosa
# 6 5.4          3.9         1.7          0.4         setosa

# %%
summary(i.setosa$Sepal.Length)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   4.300   4.800   5.000   5.006   5.200   5.800

# %%
IQR(i.setosa$Sepal.Length)
# Out:
# [1] 0.4

# %%
describe(i.setosa$Sepal.Length)
# Out:
#    vars n  mean  sd        median trimmed mad     min max range skew
# X1 1    50 5.006 0.3524897 5      5.0025  0.29652 4.3 5.8 1.5   0.1129778
#    kurtosis   se
# X1 -0.4508724 0.04984957

# %%
hist(i.setosa$Sepal.Length)
# Out:
# Plot with title “Histogram of i.setosa$Sepal.Length”
